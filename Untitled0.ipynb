# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import os
import numpy as np
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.utils import to_categorical, plot_model

from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt

# %%
DATASET_PATH = '/content/drive/MyDrive/NULP/Masters/Thesis/CodeBase/asl_dataset'

# %%
images = []
labels = []

# Список класів (букв ASL)
classes = sorted(os.listdir(DATASET_PATH))

# Завантаження зображень з кожної папки
for label in classes:
    class_path = os.path.join(DATASET_PATH, label)
    if not os.path.isdir(class_path):
        continue
    print(f'Loading images for class: {label}')
    for img_name in os.listdir(class_path):
        img_path = os.path.join(class_path, img_name)
        img = tf.keras.preprocessing.image.load_img(img_path, target_size=(64, 64))
        img = tf.keras.preprocessing.image.img_to_array(img) / 255.0  # Масштабування зображень
        images.append(img)
        labels.append(label)

# Перетворення списків у numpy-масиви
X = np.array(images)
y = np.array(labels)
# Out:
# Loading images for class: 0
# Loading images for class: 1
# Loading images for class: 2
# Loading images for class: 3
# Loading images for class: 4
# Loading images for class: 5
# Loading images for class: 6
# Loading images for class: 7
# Loading images for class: 8
# Loading images for class: 9
# Loading images for class: a
# Loading images for class: b
# Loading images for class: c
# Loading images for class: d
# Loading images for class: e
# Loading images for class: f
# Loading images for class: g
# Loading images for class: h
# Loading images for class: i
# Loading images for class: j
# Loading images for class: k
# Loading images for class: l
# Loading images for class: m
# Loading images for class: n
# Loading images for class: o
# Loading images for class: p
# Loading images for class: q
# Loading images for class: r
# Loading images for class: s
# Loading images for class: t
# Loading images for class: u
# Loading images for class: v
# Loading images for class: w
# ...

# %%
from sklearn.preprocessing import LabelEncoder

# Перетворення міток у числові значення
le = LabelEncoder()
y_encoded = le.fit_transform(y)

# Перетворення у one-hot encoding
y_one_hot = to_categorical(y_encoded, num_classes=len(classes))

# Розділення на тренувальний та тестовий набори
X_train, X_test, y_train, y_test = train_test_split(X, y_one_hot, test_size=0.2, random_state=42)

print(f"Training data shape: {X_train.shape}, Training labels shape: {y_train.shape}")
# Out:
# Training data shape: (2012, 64, 64, 3), Training labels shape: (2012, 36)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout
from tensorflow.keras import layers, models


model = models.Sequential()

# First convolutional block
model.add(layers.Conv2D(32, (3, 3), activation='relu', input_shape=(64, 64, 3)))
model.add(layers.Conv2D(32, (3, 3), activation='relu'))
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.Dropout(0.25))

# Second convolutional block
model.add(layers.Conv2D(64, (3, 3), activation='relu'))
model.add(layers.Conv2D(64, (3, 3), activation='relu'))
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.Dropout(0.25))

# Third convolutional block
model.add(layers.Conv2D(128, (3, 3), activation='relu'))
model.add(layers.Conv2D(128, (3, 3), activation='relu'))
model.add(layers.Dropout(0.25))

# Flatten and Dense layers
model.add(layers.Flatten())
model.add(layers.Dense(512, activation='relu'))
model.add(layers.Dropout(0.5))
model.add(layers.Dense(128, activation='relu'))
model.add(layers.Dropout(0.5))

# Output layer with 29 classes (for classification)
model.add(layers.Dense(36, activation='softmax'))
# Компіляція моделі
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# Перегляд архітектури моделі
model.summary()
plot_model(model, show_shapes=True, show_layer_names=True)
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ conv2d_6 (Conv2D)                    │ (None, 62, 62, 32)          │             896 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_7 (Conv2D)                    │ (None, 60, 60, 32)          │           9,248 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_2 (MaxPooling2D)       │ (None, 30, 30, 32)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_5 (Dropout)                  │ (None, 30, 30, 32)          │               0 │
# ...

# %%
from tensorflow.keras.callbacks import EarlyStopping

# Аугментація даних
datagen = ImageDataGenerator(
    rotation_range=10,
    width_shift_range=0.1,
    height_shift_range=0.1,
    horizontal_flip=True
)

# Early stopping з мінімальною дельтою
early_stopping = EarlyStopping(monitor='val_accuracy', patience=5, min_delta=0.001, restore_best_weights=True)

# Тренування
history = model.fit(datagen.flow(X_train, y_train, batch_size=64),
                        epochs=100, validation_data=(X_test, y_test),
                        callbacks=[early_stopping])
# Out:
# Epoch 1/100
# /usr/local/lib/python3.10/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 54s 2s/step - accuracy: 0.0278 - loss: 3.5946 - val_accuracy: 0.0278 - val_loss: 3.5851
# Epoch 2/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 84s 2s/step - accuracy: 0.0253 - loss: 3.5823 - val_accuracy: 0.0537 - val_loss: 3.5803
# Epoch 3/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 49s 2s/step - accuracy: 0.0479 - loss: 3.5565 - val_accuracy: 0.0895 - val_loss: 3.2851
# Epoch 4/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 82s 2s/step - accuracy: 0.0859 - loss: 3.2620 - val_accuracy: 0.1909 - val_loss: 2.7777
# Epoch 5/100
# ...

# %%
# Візуалізація кривих точності
plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Training and Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

# Візуалізація кривих втрат
plt.subplot(1, 2, 2)
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Training and Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

plt.show()

# %%
from sklearn.metrics import accuracy_score, confusion_matrix, ConfusionMatrixDisplay

# Прогнозування на тестових даних
y_pred = model.predict(X_test)
y_pred_classes = np.argmax(y_pred, axis=1)
y_true = np.argmax(y_test, axis=1)

# Обчислення точності
accuracy = accuracy_score(y_true, y_pred_classes)
print(f'Accuracy: {accuracy:.4f}')

# Побудова матриці невідповідностей
cm = confusion_matrix(y_true, y_pred_classes)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=le.classes_)
disp.plot(cmap=plt.cm.Blues)
plt.show()
